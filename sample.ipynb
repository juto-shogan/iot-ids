# %%
import pandas as pd

# %%
df = pd.read_csv("data/Iot_Network_data.csv")
print(df.head(15))
# Out:
#     packet_size  transmission_time protocol_type  bandwidth_usage     latency  \
# 0          1226          91.122098          HTTP        15.623114  550.520270
# 1           960          33.345611          HTTP        63.094117  222.891645
# 2          1394          18.012294          HTTP        80.794838   86.795792
# 3          1230          95.410847           TCP        59.551855  925.876918
# 4          1195          34.216522           TCP        38.698202  427.947049
# 5          1144          75.001099           TCP        22.323969  117.470932
# 6           221          23.809163           TCP         3.868430  625.784081
# 7           566          72.955752           UDP        29.065393   20.151620
# 8          1338          23.984060          HTTP         6.566372  704.578969
# 9           430          64.136258           TCP        76.954123  620.287041
# 10          187          44.645440           TCP         1.275529  479.894818
# ...

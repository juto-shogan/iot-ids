# %%
import pandas as pd

# %%
df = pd.read_csv("data/Iot_Network_data.csv")
print(df.head(15))
# Out:
#     packet_size  transmission_time protocol_type  bandwidth_usage     latency  \
# 0          1226          91.122098          HTTP        15.623114  550.520270
# 1           960          33.345611          HTTP        63.094117  222.891645
# 2          1394          18.012294          HTTP        80.794838   86.795792
# 3          1230          95.410847           TCP        59.551855  925.876918
# 4          1195          34.216522           TCP        38.698202  427.947049
# 5          1144          75.001099           TCP        22.323969  117.470932
# 6           221          23.809163           TCP         3.868430  625.784081
# 7           566          72.955752           UDP        29.065393   20.151620
# 8          1338          23.984060          HTTP         6.566372  704.578969
# 9           430          64.136258           TCP        76.954123  620.287041
# 10          187          44.645440           TCP         1.275529  479.894818
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        packet_size  transmission_time protocol_type  bandwidth_usage  \
# 0             1226          91.122098          HTTP        15.623114
# 1              960          33.345611          HTTP        63.094117
# 2             1394          18.012294          HTTP        80.794838
# 3             1230          95.410847           TCP        59.551855
# 4             1195          34.216522           TCP        38.698202
# ...            ...                ...           ...              ...
# 99995          280          73.263240           TCP        23.782773
# 99996          959          35.752750           UDP        61.953559
# 99997          263           1.936327          HTTP        85.248796
# 99998          389          97.668208           UDP        68.616472
# 99999          932          29.270521           TCP        95.534707
#
#           latency     jitter  packet_loss_rate  device_id device_type  \
# ...

# %%
df.columns
# Out:
# Index(['packet_size', 'transmission_time', 'protocol_type', 'bandwidth_usage',
#        'latency', 'jitter', 'packet_loss_rate', 'device_id', 'device_type',
#        'energy_usage', 'allocated_bandwidth'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# 1. Extract the trained Random Forest from your dictionary
rf_model = ml_models_dict["Random Forest"]

# 2. Get the importance scores
importances = rf_model.feature_importances_

# 3. Get feature names 
# (If X_train is a pandas DataFrame, this grabs the actual column names)
if hasattr(X_train, 'columns'):
    feature_names = X_train.columns
else:
    # Fallback if it's a raw numpy array
    feature_names = [f"Feature {i}" for i in range(X_train.shape[1])]

# 4. Sort and grab the Top 10 most important features
feat_imp_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=True).tail(10)

# 5. Plot the horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(feat_imp_df['Feature'], feat_imp_df['Importance'], color='teal', edgecolor='black')

# 6. Formatting
plt.xlabel('Relative Importance (Gini)', fontsize=12, fontweight='bold')
plt.title('Top 10 Most Important IoT Network Features', fontsize=14, fontweight='bold')
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Save the image for your Word document
plt.savefig('Feature_Importance.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       3 import numpy as np
#       5 # 1. Extract the trained Random Forest from your dictionary
# ----> 6 rf_model = ml_models_dict["Random Forest"]
#       8 # 2. Get the importance scores
#       9 importances = rf_model.feature_importances_
#
# NameError: name 'ml_models_dict' is not defined
